# %%
import pandas as pd

mrna_data = pd.read_csv('./PDAC_data/mRNA_preprocessed.csv', index_col=0)
print(mrna_data.shape)
mrna_data.head(1)
# Out:
# (137, 1500)
#                XIST     PNLIP    AMY2A  RNA18SN4  RNA18SN1  RNA18SN3  \
# C3L-00017 -0.796118 -1.774577 -1.69026  0.153086  0.153086  0.153086
#
#            RNA18SN2  RNA18SN5    CELA2A      CPA1  ...    RNF5P1       GIP  \
# C3L-00017  0.153086  0.153086 -1.281799 -1.897223  ... -0.851949 -0.648965
#
#              RIMBP2      PSG1     TRPM5  LOC105376382   DNASE2B  PIR-FIGF  \
# C3L-00017  0.832518  0.082587  1.624735     -2.602721  0.952308 -1.738352
#
#            LINC02490    FAM30A
# C3L-00017  -1.199231 -0.013946
#
# [1 rows x 1500 columns]

# %%
proteome_data = pd.read_csv('./PDAC_data/proteome_preprocessed.csv', index_col=0)
print(proteome_data.shape)
proteome_data.head(1)
# Out:
# (137, 9644)
#                A1BG      A1CF       A2M     A2ML1      AAAS      AACS  \
# C3L-00017  0.185445 -0.592399  0.964998 -0.543458 -0.727576  1.512089
#
#               AADAC     AAGAB      AAK1    AAMDC  ...    ZRANB2     ZRSR2  \
# C3L-00017 -0.475572 -0.361871 -0.994617  1.43181  ...  0.322185 -0.670025
#
#             ZSCAN18    ZSWIM8      ZW10    ZWILCH   ZYG11B      ZYX     ZZEF1  \
# C3L-00017  0.716651  0.246046  0.881191 -1.408678  0.26554 -1.48282 -0.977116
#
#                ZZZ3
# C3L-00017  0.431648
#
# [1 rows x 9644 columns]

# %%
scna_data = pd.read_csv('./PDAC_data/SCNA_preprocessed.csv', index_col=0)
print(scna_data.shape)
scna_data.head(1)
# Out:
# (137, 3000)
#               IL3RA       VCY       UTY     USP9Y     DDX3Y    TMSB4Y  \
# C3L-00017 -0.102157  2.132233  2.435571  2.435571  2.435571  2.435571
#
#               VCY1B     HSFY1     HSFY2     CDY2A  ...   CCDC167   CCDC171  \
# C3L-00017  2.440122  2.441097  2.441097  2.441097  ...  0.077383 -1.276814
#
#              RAB40B    WDR45B     FOXK2    SH3GL2  ADAMTSL1     SAXO1  \
# C3L-00017 -0.082938 -0.082938 -0.082938 -1.291565 -1.296635 -1.296729
#
#               RRAGA     HAUS6
# C3L-00017 -1.296729 -1.296729
#
# [1 rows x 3000 columns]

# %%
data = [
    [mrna_data],      
    [proteome_data],  
    [scna_data]       
]

print("Data structure prepared:")
print(f"  View 0 (mRNA): {data[0][0].shape}")
print(f"  View 1 (Proteome): {data[1][0].shape}")
print(f"  View 2 (SCNA): {data[2][0].shape}")
print(f"  All views have {data[0][0].shape[0]} samples")
# Out:
# Data structure prepared:
#   View 0 (mRNA): (137, 1500)
#   View 1 (Proteome): (137, 9644)
#   View 2 (SCNA): (137, 3000)
#   All views have 137 samples

# %%
from mofapy2.run.entry_point import entry_point

ent = entry_point()

ent.set_data_options(
    scale_views=False  # Data is already normalized
)
views_names = ["mRNA", "Proteome", "SCNA"]
groups_names = ["PDAC"]
samples_names = [mrna_data.index.tolist()]  
features_names = [
    ["mrna_" + str(col) for col in mrna_data.columns.tolist()],
    ["proteome_" + str(col) for col in proteome_data.columns.tolist()],
    ["scna_" + str(col) for col in scna_data.columns.tolist()]
]
ent.set_data_matrix(
    data, 
    views_names=views_names, 
    groups_names=groups_names, 
    samples_names=samples_names,
    features_names=features_names
)
print("Data matrix set successfully!")
# Out:
#         #########################################################
#         ###           __  __  ____  ______                    ###
#         ###          |  \/  |/ __ \|  ____/\    _             ###
#         ###          | \  / | |  | | |__ /  \ _| |_           ###
#         ###          | |\/| | |  | |  __/ /\ \_   _|          ###
#         ###          | |  | | |__| | | / ____ \|_|            ###
#         ###          |_|  |_|\____/|_|/_/    \_\              ###
#         ###                                                   ###
#         #########################################################
#
#
#
# Successfully loaded view='mRNA' group='PDAC' with N=137 samples and D=1500 features...
# Successfully loaded view='Proteome' group='PDAC' with N=137 samples and D=9644 features...
# Successfully loaded view='SCNA' group='PDAC' with N=137 samples and D=3000 features...
#
#
# Data matrix set successfully!

# %%
ent.set_model_options(
    factors=10,               # Number of latent factors
    spikeslab_weights=True,   # Sparse feature weights
    ard_weights=True          # Automatic relevance determination
)

print("Model options set!")

ent.set_train_options(
    iter=1000,                    # Maximum iterations
    convergence_mode="medium",    # Convergence speed
    dropR2=0.001,                 # Drop factors explaining < 0.1% variance
    gpu_mode=False,               # Set True if GPU available
    seed=42,                      # Reproducibility
    verbose=True                  # Show training progress
)

print("Training options set!")
# Out:
# Model options:
# - Automatic Relevance Determination prior on the factors: False
# - Automatic Relevance Determination prior on the weights: True
# - Spike-and-slab prior on the factors: False
# - Spike-and-slab prior on the weights: True
# Likelihoods:
# - View 0 (mRNA): gaussian
# - View 1 (Proteome): gaussian
# - View 2 (SCNA): gaussian
#
#
# Model options set!
#
# Dropping factors with minimum threshold of 0.001% variance explained
#
# Convergence mode: medium
#
# Training options set!

# %%
print("Building MOFA model...")
ent.build()
print("Model built!")
# Out:
# Building MOFA model...
# Model built!

# %%
print("\nTraining MOFA model... This may take a few minutes.")
ent.run()
print("Training complete!")
# Out:
# Training MOFA model... This may take a few minutes.
#
#
# ######################################
# ## Training the model with seed 42 ##
# ######################################
#
#
# ELBO before training:
# Z=-88.63  W=-182260.69  Tau=-75507.01  Y=-14251047.52  AlphaW=-919.77  ThetaW=0.00
# Total: -14509823.63
#
# Iteration 1: time=0.47, ELBO=-2950084.79, deltaELBO=11559738.834 (79.66836215%), Factors=9
# - ELBO decomposition:  Z=-2406.62  W=-119067.38  Tau=-107595.54  Y=-2720082.33  AlphaW=-932.93  ThetaW=0.00
# - Time spent in ELBO computation: 2.0%
# - Variance explained:  View 0: 6.45%   View 1: 6.25%   View 2: 4.86%
# - Fraction of zero weights:  View 0: 25%   View 1: 23%   View 2: 20%
# - Maximum correlation between factors: 0.18
# - Factor norms:  5.05 3.74 2.46 2.11 2.07 1.05 0.79 0.69 0.40
# - Tau per view (average):  View 0: 1.05   View 1: 1.04   View 2: 1.03
#
#
# Iteration 2: time=0.44, ELBO=-2747393.35, deltaELBO=202691.446 (1.39692564%), Factors=8
# - ELBO decomposition:  Z=-3557.86  W=-170492.43  Tau=-107597.21  Y=-2464916.58  AlphaW=-829.27  ThetaW=0.00
# - Time spent in ELBO computation: 2.4%
# - Variance explained:  View 0: 24.27%   View 1: 26.13%   View 2: 29.46%
# - Fraction of zero weights:  View 0: 12%   View 1: 12%   View 2: 12%
# - Maximum correlation between factors: 0.07
# - Factor norms:  4.66 3.41 2.19 1.90 1.83 1.00 0.80 0.72
# - Tau per view (average):  View 0: 1.38   View 1: 1.37   View 2: 1.62
#
#
# Iteration 3: time=0.37, ELBO=-2710704.23, deltaELBO=36689.114 (0.25285706%), Factors=8
# - ELBO decomposition:  Z=-3896.94  W=-183084.48  Tau=-107599.36  Y=-2415294.19  AlphaW=-829.27  ThetaW=0.00
# - Time spent in ELBO computation: 3.8%
# - Variance explained:  View 0: 25.49%   View 1: 27.21%   View 2: 32.10%
# - Fraction of zero weights:  View 0: 10%   View 1: 9%   View 2: 12%
# - Maximum correlation between factors: 0.12
# - Factor norms:  4.43 3.17 2.05 1.71 1.78 0.91 0.71 0.69
# - Tau per view (average):  View 0: 1.44   View 1: 1.41   View 2: 2.40
#
#
# Iteration 4: time=0.46, ELBO=-2679211.53, deltaELBO=31492.707 (0.21704403%), Factors=8
# - ELBO decomposition:  Z=-4065.77  W=-175979.24  Tau=-107604.69  Y=-2390732.56  AlphaW=-829.27  ThetaW=0.00
# - Time spent in ELBO computation: 2.6%
# - Variance explained:  View 0: 25.63%   View 1: 27.22%   View 2: 32.56%
# - Fraction of zero weights:  View 0: 8%   View 1: 8%   View 2: 13%
# - Maximum correlation between factors: 0.15
# - Factor norms:  4.22 2.95 1.98 1.55 1.78 0.84 0.65 0.70
# - Tau per view (average):  View 0: 1.45   View 1: 1.42   View 2: 4.28
#
#
# Iteration 5: time=0.55, ELBO=-2658869.86, deltaELBO=20341.666 (0.14019238%), Factors=8
# - ELBO decomposition:  Z=-4265.39  W=-167745.14  Tau=-107612.42  Y=-2378417.65  AlphaW=-829.27  ThetaW=0.00
# - Time spent in ELBO computation: 1.5%
# - Variance explained:  View 0: 25.85%   View 1: 27.42%   View 2: 32.59%
# - Fraction of zero weights:  View 0: 7%   View 1: 6%   View 2: 12%
# - Maximum correlation between factors: 0.16
# - Factor norms:  4.06 2.75 1.94 1.42 1.79 0.79 0.60 0.71
# - Tau per view (average):  View 0: 1.45   View 1: 1.42   View 2: 6.90
#
#
# Iteration 6: time=0.38, ELBO=-2643081.63, deltaELBO=15788.230 (0.10881063%), Factors=8
# - ELBO decomposition:  Z=-4429.25  W=-160730.93  Tau=-107629.45  Y=-2369462.73  AlphaW=-829.27  ThetaW=0.00
# - Time spent in ELBO computation: 5.6%
# - Variance explained:  View 0: 26.08%   View 1: 27.61%   View 2: 32.63%
# - Fraction of zero weights:  View 0: 6%   View 1: 5%   View 2: 11%
# - Maximum correlation between factors: 0.17
# - Factor norms:  3.95 2.60 1.92 1.33 1.80 0.76 0.58 0.72
# - Tau per view (average):  View 0: 1.46   View 1: 1.42   View 2: 12.61
#
#
# Iteration 7: time=0.68, ELBO=-2629265.09, deltaELBO=13816.540 (0.09522197%), Factors=8
# - ELBO decomposition:  Z=-4642.61  W=-155355.43  Tau=-107706.20  Y=-2360731.59  AlphaW=-829.27  ThetaW=0.00
# - Time spent in ELBO computation: 4.8%
# - Variance explained:  View 0: 26.25%   View 1: 27.70%   View 2: 32.61%
# - Fraction of zero weights:  View 0: 5%   View 1: 4%   View 2: 10%
# - Maximum correlation between factors: 0.18
# - Factor norms:  3.89 2.48 1.92 1.27 1.81 0.75 0.56 0.72
# - Tau per view (average):  View 0: 1.47   View 1: 1.43   View 2: 38.23
#
#
# Iteration 8: time=0.56, ELBO=-2618153.41, deltaELBO=11111.679 (0.07658039%), Factors=8
# - ELBO decomposition:  Z=-5018.51  W=-151511.81  Tau=-108102.67  Y=-2352691.15  AlphaW=-829.27  ThetaW=0.00
# - Time spent in ELBO computation: 2.2%
# - Variance explained:  View 0: 26.37%   View 1: 27.74%   View 2: 32.61%
# - Fraction of zero weights:  View 0: 4%   View 1: 4%   View 2: 8%
# - Maximum correlation between factors: 0.18
# - Factor norms:  3.87 2.40 1.92 1.23 1.81 0.74 0.56 0.72
# - Tau per view (average):  View 0: 1.47   View 1: 1.42   View 2: 170.43
#
#
# Iteration 9: time=0.90, ELBO=-2611490.63, deltaELBO=6662.779 (0.04591909%), Factors=8
# - ELBO decomposition:  Z=-5523.03  W=-148742.17  Tau=-109050.67  Y=-2347345.49  AlphaW=-829.27  ThetaW=0.00
# - Time spent in ELBO computation: 2.0%
# - Variance explained:  View 0: 26.45%   View 1: 27.77%   View 2: 32.65%
# - Fraction of zero weights:  View 0: 4%   View 1: 4%   View 2: 8%
# - Maximum correlation between factors: 0.18
# - Factor norms:  3.87 2.35 1.92 1.21 1.81 0.74 0.55 0.72
# - Tau per view (average):  View 0: 1.47   View 1: 1.42   View 2: 486.45
#
#
# Iteration 10: time=0.48, ELBO=-2607763.89, deltaELBO=3726.744 (0.02568428%), Factors=8
# - ELBO decomposition:  Z=-5886.45  W=-146579.84  Tau=-109707.92  Y=-2344760.40  AlphaW=-829.27  ThetaW=0.00
# - Time spent in ELBO computation: 3.1%
# - Variance explained:  View 0: 26.50%   View 1: 27.80%   View 2: 32.70%
# - Fraction of zero weights:  View 0: 3%   View 1: 3%   View 2: 7%
# - Maximum correlation between factors: 0.18
# - Factor norms:  3.87 2.31 1.92 1.19 1.81 0.74 0.55 0.72
# - Tau per view (average):  View 0: 1.47   View 1: 1.43   View 2: 705.54
#
#
# Iteration 11: time=0.51, ELBO=-2604961.90, deltaELBO=2801.990 (0.01931099%), Factors=8
# - ELBO decomposition:  Z=-6024.61  W=-144765.97  Tau=-109881.30  Y=-2343460.75  AlphaW=-829.27  ThetaW=0.00
# - Time spent in ELBO computation: 2.7%
# - Variance explained:  View 0: 26.52%   View 1: 27.81%   View 2: 32.74%
# - Fraction of zero weights:  View 0: 3%   View 1: 3%   View 2: 7%
# - Maximum correlation between factors: 0.18
# - Factor norms:  3.87 2.28 1.92 1.17 1.81 0.74 0.55 0.72
# - Tau per view (average):  View 0: 1.47   View 1: 1.43   View 2: 763.33
#
#
# Iteration 12: time=0.44, ELBO=-2602138.39, deltaELBO=2823.509 (0.01945929%), Factors=8
# - ELBO decomposition:  Z=-6072.11  W=-143251.43  Tau=-109948.04  Y=-2342037.54  AlphaW=-829.27  ThetaW=0.00
# - Time spent in ELBO computation: 3.6%
# - Variance explained:  View 0: 26.51%   View 1: 27.80%   View 2: 32.75%
# - Fraction of zero weights:  View 0: 3%   View 1: 3%   View 2: 7%
# - Maximum correlation between factors: 0.18
# - Factor norms:  3.87 2.26 1.92 1.15 1.82 0.74 0.55 0.72
# - Tau per view (average):  View 0: 1.47   View 1: 1.43   View 2: 785.59
#
#
# Iteration 13: time=0.45, ELBO=-2598836.53, deltaELBO=3301.861 (0.02275604%), Factors=8
# - ELBO decomposition:  Z=-6127.47  W=-142018.89  Tau=-110126.27  Y=-2339734.62  AlphaW=-829.27  ThetaW=0.00
# - Time spent in ELBO computation: 6.0%
# - Variance explained:  View 0: 26.48%   View 1: 27.79%   View 2: 32.74%
# - Fraction of zero weights:  View 0: 3%   View 1: 3%   View 2: 7%
# - Maximum correlation between factors: 0.19
# - Factor norms:  3.87 2.24 1.92 1.14 1.82 0.74 0.55 0.72
# - Tau per view (average):  View 0: 1.47   View 1: 1.43   View 2: 845.01
#
#
# Iteration 14: time=0.46, ELBO=-2595817.16, deltaELBO=3019.369 (0.02080914%), Factors=8
# - ELBO decomposition:  Z=-6237.84  W=-141050.34  Tau=-110710.21  Y=-2336989.50  AlphaW=-829.27  ThetaW=0.00
# - Time spent in ELBO computation: 4.0%
# - Variance explained:  View 0: 26.44%   View 1: 27.78%   View 2: 32.72%
# - Fraction of zero weights:  View 0: 3%   View 1: 3%   View 2: 7%
# - Maximum correlation between factors: 0.19
# - Factor norms:  3.87 2.23 1.92 1.12 1.82 0.74 0.55 0.72
# - Tau per view (average):  View 0: 1.47   View 1: 1.43   View 2: 1039.66
#
#
# Iteration 15: time=0.43, ELBO=-2594420.56, deltaELBO=1396.595 (0.00962517%), Factors=8
# - ELBO decomposition:  Z=-6394.45  W=-140298.66  Tau=-111219.49  Y=-2335678.70  AlphaW=-829.27  ThetaW=0.00
# - Time spent in ELBO computation: 2.2%
# - Variance explained:  View 0: 26.40%   View 1: 27.76%   View 2: 32.72%
# - Fraction of zero weights:  View 0: 3%   View 1: 3%   View 2: 6%
# - Maximum correlation between factors: 0.19
# - Factor norms:  3.87 2.22 1.92 1.11 1.82 0.74 0.55 0.72
# - Tau per view (average):  View 0: 1.47   View 1: 1.43   View 2: 1209.43
#
#
# Iteration 16: time=0.45, ELBO=-2593767.20, deltaELBO=653.366 (0.00450292%), Factors=8
# - ELBO decomposition:  Z=-6472.22  W=-139683.25  Tau=-111342.70  Y=-2335439.77  AlphaW=-829.27  ThetaW=0.00
# - Time spent in ELBO computation: 2.3%
# - Variance explained:  View 0: 26.36%   View 1: 27.74%   View 2: 32.71%
# - Fraction of zero weights:  View 0: 3%   View 1: 3%   View 2: 6%
# - Maximum correlation between factors: 0.19
# - Factor norms:  3.87 2.21 1.92 1.10 1.82 0.74 0.55 0.72
# - Tau per view (average):  View 0: 1.47   View 1: 1.43   View 2: 1250.49
#
#
# Iteration 17: time=0.44, ELBO=-2593295.76, deltaELBO=471.437 (0.00324909%), Factors=8
# - ELBO decomposition:  Z=-6487.26  W=-139178.52  Tau=-111363.60  Y=-2335437.11  AlphaW=-829.27  ThetaW=0.00
# - Time spent in ELBO computation: 2.5%
# - Variance explained:  View 0: 26.32%   View 1: 27.73%   View 2: 32.71%
# - Fraction of zero weights:  View 0: 3%   View 1: 3%   View 2: 6%
# - Maximum correlation between factors: 0.19
# - Factor norms:  3.87 2.21 1.92 1.08 1.82 0.74 0.55 0.72
# - Tau per view (average):  View 0: 1.47   View 1: 1.43   View 2: 1257.46
#
#
# Iteration 18: time=0.35, ELBO=-2592928.13, deltaELBO=367.631 (0.00253367%), Factors=8
# - ELBO decomposition:  Z=-6489.48  W=-138767.26  Tau=-111367.23  Y=-2335474.89  AlphaW=-829.27  ThetaW=0.00
# - Time spent in ELBO computation: 3.0%
# - Variance explained:  View 0: 26.29%   View 1: 27.71%   View 2: 32.71%
# - Fraction of zero weights:  View 0: 3%   View 1: 3%   View 2: 6%
# - Maximum correlation between factors: 0.19
# - Factor norms:  3.87 2.20 1.92 1.07 1.82 0.74 0.55 0.72
# - Tau per view (average):  View 0: 1.47   View 1: 1.43   View 2: 1258.67
#
#
# Iteration 19: time=0.45, ELBO=-2592634.47, deltaELBO=293.664 (0.00202390%), Factors=8
# - ELBO decomposition:  Z=-6489.69  W=-138430.61  Tau=-111367.90  Y=-2335517.00  AlphaW=-829.27  ThetaW=0.00
# - Time spent in ELBO computation: 3.1%
# - Variance explained:  View 0: 26.26%   View 1: 27.70%   View 2: 32.70%
# - Fraction of zero weights:  View 0: 3%   View 1: 3%   View 2: 6%
# - Maximum correlation between factors: 0.19
# - Factor norms:  3.87 2.19 1.92 1.06 1.82 0.74 0.55 0.72
# - Tau per view (average):  View 0: 1.47   View 1: 1.43   View 2: 1258.90
#
#
# Iteration 20: time=0.43, ELBO=-2592397.09, deltaELBO=237.379 (0.00163599%), Factors=8
# - ELBO decomposition:  Z=-6489.57  W=-138154.31  Tau=-111368.03  Y=-2335555.91  AlphaW=-829.27  ThetaW=0.00
# - Time spent in ELBO computation: 2.6%
# - Variance explained:  View 0: 26.23%   View 1: 27.69%   View 2: 32.69%
# - Fraction of zero weights:  View 0: 3%   View 1: 3%   View 2: 6%
# - Maximum correlation between factors: 0.19
# - Factor norms:  3.87 2.19 1.92 1.05 1.82 0.74 0.55 0.72
# - Tau per view (average):  View 0: 1.47   View 1: 1.43   View 2: 1258.94
#
#
# Iteration 21: time=0.38, ELBO=-2592204.72, deltaELBO=192.371 (0.00132580%), Factors=8
# - ELBO decomposition:  Z=-6489.41  W=-137927.75  Tau=-111368.05  Y=-2335590.24  AlphaW=-829.27  ThetaW=0.00
# - Time spent in ELBO computation: 2.3%
# - Variance explained:  View 0: 26.21%   View 1: 27.68%   View 2: 32.68%
# - Fraction of zero weights:  View 0: 3%   View 1: 3%   View 2: 6%
# - Maximum correlation between factors: 0.19
# - Factor norms:  3.87 2.18 1.92 1.04 1.82 0.74 0.55 0.72
# - Tau per view (average):  View 0: 1.47   View 1: 1.43   View 2: 1258.95
#
#
# Iteration 22: time=0.69, ELBO=-2592048.90, deltaELBO=155.821 (0.00107390%), Factors=8
# - ELBO decomposition:  Z=-6489.26  W=-137742.31  Tau=-111368.05  Y=-2335620.00  AlphaW=-829.27  ThetaW=0.00
# - Time spent in ELBO computation: 2.2%
# - Variance explained:  View 0: 26.20%   View 1: 27.67%   View 2: 32.66%
# - Fraction of zero weights:  View 0: 3%   View 1: 3%   View 2: 6%
# - Maximum correlation between factors: 0.19
# - Factor norms:  3.87 2.18 1.92 1.03 1.82 0.74 0.55 0.72
# - Tau per view (average):  View 0: 1.47   View 1: 1.43   View 2: 1258.95
#
#
# Iteration 23: time=0.41, ELBO=-2591922.36, deltaELBO=126.535 (0.00087206%), Factors=8
# - ELBO decomposition:  Z=-6489.12  W=-137590.56  Tau=-111368.05  Y=-2335645.36  AlphaW=-829.27  ThetaW=0.00
# - Time spent in ELBO computation: 3.6%
# - Variance explained:  View 0: 26.18%   View 1: 27.67%   View 2: 32.64%
# - Fraction of zero weights:  View 0: 3%   View 1: 3%   View 2: 6%
# - Maximum correlation between factors: 0.19
# - Factor norms:  3.87 2.18 1.92 1.03 1.82 0.74 0.55 0.72
# - Tau per view (average):  View 0: 1.47   View 1: 1.43   View 2: 1258.95
#
#
# Iteration 24: time=0.54, ELBO=-2591818.77, deltaELBO=103.593 (0.00071395%), Factors=8
# - ELBO decomposition:  Z=-6488.99  W=-137466.10  Tau=-111368.05  Y=-2335666.35  AlphaW=-829.27  ThetaW=0.00
# - Time spent in ELBO computation: 2.7%
# - Variance explained:  View 0: 26.17%   View 1: 27.66%   View 2: 32.62%
# - Fraction of zero weights:  View 0: 3%   View 1: 3%   View 2: 6%
# - Maximum correlation between factors: 0.19
# - Factor norms:  3.87 2.17 1.92 1.02 1.82 0.74 0.55 0.72
# - Tau per view (average):  View 0: 1.47   View 1: 1.43   View 2: 1258.95
#
#
# Iteration 25: time=0.38, ELBO=-2591732.82, deltaELBO=85.942 (0.00059230%), Factors=8
# - ELBO decomposition:  Z=-6488.87  W=-137363.57  Tau=-111368.06  Y=-2335683.07  AlphaW=-829.27  ThetaW=0.00
# - Time spent in ELBO computation: 2.7%
# - Variance explained:  View 0: 26.16%   View 1: 27.66%   View 2: 32.60%
# - Fraction of zero weights:  View 0: 3%   View 1: 3%   View 2: 6%
# - Maximum correlation between factors: 0.19
# - Factor norms:  3.87 2.17 1.92 1.01 1.82 0.74 0.55 0.72
# - Tau per view (average):  View 0: 1.47   View 1: 1.43   View 2: 1258.95
#
#
# Iteration 26: time=0.34, ELBO=-2591660.35, deltaELBO=72.478 (0.00049951%), Factors=8
# - ELBO decomposition:  Z=-6488.75  W=-137278.58  Tau=-111368.07  Y=-2335695.68  AlphaW=-829.27  ThetaW=0.00
# - Time spent in ELBO computation: 2.6%
# - Variance explained:  View 0: 26.15%   View 1: 27.66%   View 2: 32.58%
# - Fraction of zero weights:  View 0: 3%   View 1: 3%   View 2: 6%
# - Maximum correlation between factors: 0.19
# - Factor norms:  3.87 2.17 1.92 1.01 1.82 0.74 0.55 0.72
# - Tau per view (average):  View 0: 1.47   View 1: 1.43   View 2: 1258.95
#
#
# Iteration 27: time=0.45, ELBO=-2591598.14, deltaELBO=62.207 (0.00042872%), Factors=8
# - ELBO decomposition:  Z=-6488.64  W=-137207.64  Tau=-111368.08  Y=-2335704.51  AlphaW=-829.27  ThetaW=0.00
# - Time spent in ELBO computation: 3.9%
# - Variance explained:  View 0: 26.14%   View 1: 27.66%   View 2: 32.56%
# - Fraction of zero weights:  View 0: 3%   View 1: 3%   View 2: 6%
# - Maximum correlation between factors: 0.19
# - Factor norms:  3.87 2.16 1.92 1.01 1.82 0.74 0.55 0.72
# - Tau per view (average):  View 0: 1.47   View 1: 1.43   View 2: 1258.95
#
#
# Iteration 28: time=0.37, ELBO=-2591543.81, deltaELBO=54.325 (0.00037440%), Factors=8
# - ELBO decomposition:  Z=-6488.54  W=-137147.99  Tau=-111368.09  Y=-2335709.92  AlphaW=-829.27  ThetaW=0.00
# - Time spent in ELBO computation: 2.5%
# - Variance explained:  View 0: 26.13%   View 1: 27.66%   View 2: 32.55%
# - Fraction of zero weights:  View 0: 3%   View 1: 3%   View 2: 6%
# - Maximum correlation between factors: 0.19
# - Factor norms:  3.87 2.16 1.92 1.00 1.82 0.74 0.55 0.72
# - Tau per view (average):  View 0: 1.47   View 1: 1.43   View 2: 1258.96
#
#
# Iteration 29: time=0.35, ELBO=-2591495.60, deltaELBO=48.217 (0.00033231%), Factors=8
# - ELBO decomposition:  Z=-6488.44  W=-137097.44  Tau=-111368.11  Y=-2335712.34  AlphaW=-829.27  ThetaW=0.00
# - Time spent in ELBO computation: 2.9%
# - Variance explained:  View 0: 26.12%   View 1: 27.66%   View 2: 32.53%
# - Fraction of zero weights:  View 0: 3%   View 1: 3%   View 2: 6%
# - Maximum correlation between factors: 0.19
# - Factor norms:  3.87 2.15 1.92 1.00 1.82 0.74 0.55 0.72
# - Tau per view (average):  View 0: 1.47   View 1: 1.43   View 2: 1258.96
#
#
# Iteration 30: time=0.39, ELBO=-2591452.17, deltaELBO=43.429 (0.00029931%), Factors=8
# - ELBO decomposition:  Z=-6488.34  W=-137054.26  Tau=-111368.13  Y=-2335712.16  AlphaW=-829.27  ThetaW=0.00
# - Time spent in ELBO computation: 2.4%
# - Variance explained:  View 0: 26.12%   View 1: 27.66%   View 2: 32.52%
# - Fraction of zero weights:  View 0: 3%   View 1: 3%   View 2: 6%
# - Maximum correlation between factors: 0.19
# - Factor norms:  3.87 2.15 1.92 0.99 1.82 0.74 0.55 0.72
# - Tau per view (average):  View 0: 1.47   View 1: 1.43   View 2: 1258.97
#
#
# Iteration 31: time=0.37, ELBO=-2591412.54, deltaELBO=39.628 (0.00027311%), Factors=8
# - ELBO decomposition:  Z=-6488.25  W=-137017.11  Tau=-111368.15  Y=-2335709.77  AlphaW=-829.27  ThetaW=0.00
# - Time spent in ELBO computation: 4.3%
# - Variance explained:  View 0: 26.11%   View 1: 27.66%   View 2: 32.51%
# - Fraction of zero weights:  View 0: 3%   View 1: 3%   View 2: 6%
# - Maximum correlation between factors: 0.19
# - Factor norms:  3.87 2.15 1.92 0.99 1.82 0.74 0.55 0.72
# - Tau per view (average):  View 0: 1.47   View 1: 1.43   View 2: 1258.98
#
#
# Iteration 32: time=0.43, ELBO=-2591375.97, deltaELBO=36.573 (0.00025206%), Factors=8
# - ELBO decomposition:  Z=-6488.16  W=-136984.88  Tau=-111368.18  Y=-2335705.48  AlphaW=-829.27  ThetaW=0.00
# - Time spent in ELBO computation: 2.8%
# - Variance explained:  View 0: 26.11%   View 1: 27.66%   View 2: 32.50%
# - Fraction of zero weights:  View 0: 3%   View 1: 3%   View 2: 6%
# - Maximum correlation between factors: 0.19
# - Factor norms:  3.87 2.14 1.92 0.99 1.82 0.74 0.55 0.72
# - Tau per view (average):  View 0: 1.47   View 1: 1.43   View 2: 1258.99
#
#
# Iteration 33: time=0.37, ELBO=-2591341.88, deltaELBO=34.086 (0.00023492%), Factors=8
# - ELBO decomposition:  Z=-6488.07  W=-136956.74  Tau=-111368.20  Y=-2335699.60  AlphaW=-829.27  ThetaW=0.00
# - Time spent in ELBO computation: 3.6%
# - Variance explained:  View 0: 26.11%   View 1: 27.66%   View 2: 32.49%
# - Fraction of zero weights:  View 0: 3%   View 1: 3%   View 2: 6%
# - Maximum correlation between factors: 0.19
# - Factor norms:  3.87 2.14 1.92 0.99 1.82 0.74 0.55 0.72
# - Tau per view (average):  View 0: 1.47   View 1: 1.43   View 2: 1258.99
#
#
# Iteration 34: time=0.36, ELBO=-2591309.85, deltaELBO=32.035 (0.00022078%), Factors=8
# - ELBO decomposition:  Z=-6487.98  W=-136931.98  Tau=-111368.23  Y=-2335692.39  AlphaW=-829.27  ThetaW=0.00
# - Time spent in ELBO computation: 5.5%
# - Variance explained:  View 0: 26.10%   View 1: 27.66%   View 2: 32.48%
# - Fraction of zero weights:  View 0: 3%   View 1: 3%   View 2: 6%
# - Maximum correlation between factors: 0.19
# - Factor norms:  3.86 2.14 1.92 0.98 1.82 0.74 0.55 0.72
# - Tau per view (average):  View 0: 1.47   View 1: 1.43   View 2: 1259.00
#
#
# Iteration 35: time=0.38, ELBO=-2591279.52, deltaELBO=30.325 (0.00020899%), Factors=8
# - ELBO decomposition:  Z=-6487.90  W=-136910.05  Tau=-111368.26  Y=-2335684.04  AlphaW=-829.27  ThetaW=0.00
# - Time spent in ELBO computation: 4.9%
# - Variance explained:  View 0: 26.10%   View 1: 27.66%   View 2: 32.47%
# - Fraction of zero weights:  View 0: 3%   View 1: 3%   View 2: 6%
# - Maximum correlation between factors: 0.19
# - Factor norms:  3.86 2.13 1.92 0.98 1.82 0.74 0.55 0.72
# - Tau per view (average):  View 0: 1.47   View 1: 1.43   View 2: 1259.01
#
#
# Iteration 36: time=0.46, ELBO=-2591250.64, deltaELBO=28.880 (0.00019904%), Factors=8
# - ELBO decomposition:  Z=-6487.82  W=-136890.51  Tau=-111368.29  Y=-2335674.76  AlphaW=-829.27  ThetaW=0.00
# - Time spent in ELBO computation: 4.5%
# - Variance explained:  View 0: 26.10%   View 1: 27.66%   View 2: 32.47%
# - Fraction of zero weights:  View 0: 3%   View 1: 3%   View 2: 6%
# - Maximum correlation between factors: 0.19
# - Factor norms:  3.86 2.13 1.92 0.98 1.82 0.74 0.55 0.72
# - Tau per view (average):  View 0: 1.47   View 1: 1.43   View 2: 1259.02
#
#
# Iteration 37: time=0.40, ELBO=-2591223.00, deltaELBO=27.646 (0.00019053%), Factors=8
# - ELBO decomposition:  Z=-6487.73  W=-136873.00  Tau=-111368.32  Y=-2335664.68  AlphaW=-829.27  ThetaW=0.00
# - Time spent in ELBO computation: 2.3%
# - Variance explained:  View 0: 26.09%   View 1: 27.66%   View 2: 32.46%
# - Fraction of zero weights:  View 0: 3%   View 1: 3%   View 2: 6%
# - Maximum correlation between factors: 0.19
# - Factor norms:  3.86 2.13 1.92 0.98 1.82 0.74 0.55 0.72
# - Tau per view (average):  View 0: 1.47   View 1: 1.43   View 2: 1259.03
#
#
# Iteration 38: time=0.40, ELBO=-2591196.42, deltaELBO=26.580 (0.00018319%), Factors=8
# - ELBO decomposition:  Z=-6487.65  W=-136857.20  Tau=-111368.35  Y=-2335653.95  AlphaW=-829.27  ThetaW=0.00
# - Time spent in ELBO computation: 5.7%
# - Variance explained:  View 0: 26.09%   View 1: 27.66%   View 2: 32.45%
# - Fraction of zero weights:  View 0: 3%   View 1: 3%   View 2: 6%
# - Maximum correlation between factors: 0.19
# - Factor norms:  3.86 2.12 1.92 0.98 1.82 0.74 0.55 0.72
# - Tau per view (average):  View 0: 1.47   View 1: 1.43   View 2: 1259.04
#
#
# Iteration 39: time=0.44, ELBO=-2591170.77, deltaELBO=25.649 (0.00017677%), Factors=8
# - ELBO decomposition:  Z=-6487.57  W=-136842.88  Tau=-111368.38  Y=-2335642.67  AlphaW=-829.27  ThetaW=0.00
# - Time spent in ELBO computation: 2.1%
# - Variance explained:  View 0: 26.09%   View 1: 27.66%   View 2: 32.45%
# - Fraction of zero weights:  View 0: 3%   View 1: 3%   View 2: 6%
# - Maximum correlation between factors: 0.19
# - Factor norms:  3.86 2.12 1.93 0.97 1.82 0.74 0.55 0.72
# - Tau per view (average):  View 0: 1.47   View 1: 1.43   View 2: 1259.05
#
#
# Iteration 40: time=0.68, ELBO=-2591145.94, deltaELBO=24.828 (0.00017111%), Factors=8
# - ELBO decomposition:  Z=-6487.50  W=-136829.83  Tau=-111368.41  Y=-2335630.93  AlphaW=-829.27  ThetaW=0.00
# - Time spent in ELBO computation: 2.0%
# - Variance explained:  View 0: 26.09%   View 1: 27.66%   View 2: 32.44%
# - Fraction of zero weights:  View 0: 3%   View 1: 3%   View 2: 6%
# - Maximum correlation between factors: 0.19
# - Factor norms:  3.86 2.12 1.93 0.97 1.82 0.74 0.55 0.72
# - Tau per view (average):  View 0: 1.47   View 1: 1.43   View 2: 1259.06
#
#
# Iteration 41: time=0.41, ELBO=-2591121.84, deltaELBO=24.097 (0.00016607%), Factors=8
# - ELBO decomposition:  Z=-6487.42  W=-136817.89  Tau=-111368.45  Y=-2335618.81  AlphaW=-829.27  ThetaW=0.00
# - Time spent in ELBO computation: 2.4%
# - Variance explained:  View 0: 26.09%   View 1: 27.67%   View 2: 32.44%
# - Fraction of zero weights:  View 0: 3%   View 1: 3%   View 2: 6%
# - Maximum correlation between factors: 0.19
# - Factor norms:  3.86 2.12 1.93 0.97 1.82 0.74 0.55 0.72
# - Tau per view (average):  View 0: 1.47   View 1: 1.43   View 2: 1259.07
#
#
# Iteration 42: time=0.40, ELBO=-2591098.40, deltaELBO=23.440 (0.00016155%), Factors=8
# - ELBO decomposition:  Z=-6487.34  W=-136806.92  Tau=-111368.48  Y=-2335606.39  AlphaW=-829.27  ThetaW=0.00
# - Time spent in ELBO computation: 5.3%
# - Variance explained:  View 0: 26.09%   View 1: 27.67%   View 2: 32.43%
# - Fraction of zero weights:  View 0: 3%   View 1: 3%   View 2: 6%
# - Maximum correlation between factors: 0.19
# - Factor norms:  3.86 2.11 1.93 0.97 1.82 0.74 0.55 0.72
# - Tau per view (average):  View 0: 1.47   View 1: 1.43   View 2: 1259.09
#
#
# Iteration 43: time=0.50, ELBO=-2591075.56, deltaELBO=22.844 (0.00015744%), Factors=8
# - ELBO decomposition:  Z=-6487.27  W=-136796.79  Tau=-111368.51  Y=-2335593.71  AlphaW=-829.27  ThetaW=0.00
# - Time spent in ELBO computation: 1.7%
# - Variance explained:  View 0: 26.09%   View 1: 27.67%   View 2: 32.43%
# - Fraction of zero weights:  View 0: 3%   View 1: 3%   View 2: 6%
# - Maximum correlation between factors: 0.19
# - Factor norms:  3.86 2.11 1.93 0.97 1.82 0.74 0.55 0.72
# - Tau per view (average):  View 0: 1.47   View 1: 1.43   View 2: 1259.10
#
#
# Iteration 44: time=0.49, ELBO=-2591053.26, deltaELBO=22.300 (0.00015369%), Factors=8
# - ELBO decomposition:  Z=-6487.20  W=-136787.41  Tau=-111368.55  Y=-2335580.83  AlphaW=-829.27  ThetaW=0.00
# - Time spent in ELBO computation: 2.3%
# - Variance explained:  View 0: 26.09%   View 1: 27.67%   View 2: 32.43%
# - Fraction of zero weights:  View 0: 3%   View 1: 3%   View 2: 6%
# - Maximum correlation between factors: 0.19
# - Factor norms:  3.86 2.11 1.93 0.97 1.82 0.74 0.55 0.72
# - Tau per view (average):  View 0: 1.47   View 1: 1.43   View 2: 1259.11
#
#
# Iteration 45: time=0.53, ELBO=-2591031.46, deltaELBO=21.799 (0.00015023%), Factors=8
# - ELBO decomposition:  Z=-6487.12  W=-136778.70  Tau=-111368.58  Y=-2335567.79  AlphaW=-829.27  ThetaW=0.00
# - Time spent in ELBO computation: 1.8%
# - Variance explained:  View 0: 26.08%   View 1: 27.67%   View 2: 32.42%
# - Fraction of zero weights:  View 0: 3%   View 1: 3%   View 2: 6%
# - Maximum correlation between factors: 0.19
# - Factor norms:  3.86 2.10 1.93 0.96 1.82 0.74 0.55 0.72
# - Tau per view (average):  View 0: 1.47   View 1: 1.43   View 2: 1259.12
#
#
# Iteration 46: time=0.49, ELBO=-2591010.12, deltaELBO=21.334 (0.00014703%), Factors=8
# - ELBO decomposition:  Z=-6487.05  W=-136770.57  Tau=-111368.62  Y=-2335554.61  AlphaW=-829.27  ThetaW=0.00
# - Time spent in ELBO computation: 2.2%
# - Variance explained:  View 0: 26.08%   View 1: 27.67%   View 2: 32.42%
# - Fraction of zero weights:  View 0: 3%   View 1: 3%   View 2: 6%
# - Maximum correlation between factors: 0.19
# - Factor norms:  3.86 2.10 1.93 0.96 1.82 0.74 0.55 0.72
# - Tau per view (average):  View 0: 1.47   View 1: 1.43   View 2: 1259.13
#
#
# Iteration 47: time=0.39, ELBO=-2590989.22, deltaELBO=20.902 (0.00014405%), Factors=8
# - ELBO decomposition:  Z=-6486.98  W=-136762.98  Tau=-111368.65  Y=-2335541.34  AlphaW=-829.27  ThetaW=0.00
# - Time spent in ELBO computation: 2.3%
# - Variance explained:  View 0: 26.08%   View 1: 27.67%   View 2: 32.42%
# - Fraction of zero weights:  View 0: 3%   View 1: 3%   View 2: 6%
# - Maximum correlation between factors: 0.19
# - Factor norms:  3.86 2.10 1.93 0.96 1.82 0.74 0.55 0.72
# - Tau per view (average):  View 0: 1.47   View 1: 1.43   View 2: 1259.14
#
#
# Iteration 48: time=0.46, ELBO=-2590968.73, deltaELBO=20.496 (0.00014126%), Factors=8
# - ELBO decomposition:  Z=-6486.91  W=-136755.86  Tau=-111368.69  Y=-2335528.00  AlphaW=-829.27  ThetaW=0.00
# - Time spent in ELBO computation: 2.5%
# - Variance explained:  View 0: 26.08%   View 1: 27.67%   View 2: 32.42%
# - Fraction of zero weights:  View 0: 3%   View 1: 3%   View 2: 6%
# - Maximum correlation between factors: 0.19
# - Factor norms:  3.86 2.09 1.93 0.96 1.82 0.74 0.55 0.72
# - Tau per view (average):  View 0: 1.47   View 1: 1.43   View 2: 1259.15
#
#
# Iteration 49: time=0.41, ELBO=-2590948.61, deltaELBO=20.114 (0.00013862%), Factors=8
# - ELBO decomposition:  Z=-6486.84  W=-136749.17  Tau=-111368.72  Y=-2335514.62  AlphaW=-829.27  ThetaW=0.00
# - Time spent in ELBO computation: 2.1%
# - Variance explained:  View 0: 26.08%   View 1: 27.67%   View 2: 32.41%
# - Fraction of zero weights:  View 0: 3%   View 1: 3%   View 2: 6%
# - Maximum correlation between factors: 0.19
# - Factor norms:  3.86 2.09 1.93 0.96 1.82 0.74 0.55 0.72
# - Tau per view (average):  View 0: 1.47   View 1: 1.43   View 2: 1259.17
#
#
# Iteration 50: time=0.44, ELBO=-2554579.37, deltaELBO=36369.244 (0.25065256%), Factors=8
# - ELBO decomposition:  Z=-6486.77  W=-100312.45  Tau=-111368.76  Y=-2335501.20  AlphaW=-829.27  ThetaW=-80.93
# - Time spent in ELBO computation: 2.0%
# - Variance explained:  View 0: 26.08%   View 1: 27.67%   View 2: 32.41%
# - Fraction of zero weights:  View 0: 3%   View 1: 3%   View 2: 6%
# - Maximum correlation between factors: 0.19
# - Factor norms:  3.86 2.09 1.93 0.96 1.82 0.74 0.55 0.72
# - Tau per view (average):  View 0: 1.47   View 1: 1.43   View 2: 1259.18
#
#
# Iteration 51: time=0.41, ELBO=-2553508.29, deltaELBO=1071.081 (0.00738176%), Factors=8
# - ELBO decomposition:  Z=-6487.26  W=-101507.36  Tau=-111369.02  Y=-2333233.90  AlphaW=-829.27  ThetaW=-81.47
# - Time spent in ELBO computation: 2.3%
# - Variance explained:  View 0: 26.33%   View 1: 27.96%   View 2: 32.50%
# - Fraction of zero weights:  View 0: 2%   View 1: 2%   View 2: 6%
# - Maximum correlation between factors: 0.19
# - Factor norms:  3.86 2.07 1.93 0.95 1.82 0.74 0.55 0.72
# - Tau per view (average):  View 0: 1.48   View 1: 1.43   View 2: 1259.26
#
#
# Iteration 52: time=0.45, ELBO=-2552683.23, deltaELBO=825.053 (0.00568617%), Factors=8
# - ELBO decomposition:  Z=-6487.51  W=-101899.86  Tau=-111369.20  Y=-2332015.38  AlphaW=-829.27  ThetaW=-82.02
# - Time spent in ELBO computation: 4.1%
# - Variance explained:  View 0: 26.46%   View 1: 28.12%   View 2: 32.53%
# - Fraction of zero weights:  View 0: 2%   View 1: 2%   View 2: 6%
# - Maximum correlation between factors: 0.19
# - Factor norms:  3.86 2.05 1.93 0.93 1.82 0.74 0.55 0.72
# - Tau per view (average):  View 0: 1.48   View 1: 1.43   View 2: 1259.32
#
#
# Iteration 53: time=0.45, ELBO=-2552081.36, deltaELBO=601.877 (0.00414806%), Factors=8
# - ELBO decomposition:  Z=-6487.48  W=-101996.25  Tau=-111369.36  Y=-2331316.47  AlphaW=-829.27  ThetaW=-82.54
# - Time spent in ELBO computation: 2.4%
# - Variance explained:  View 0: 26.53%   View 1: 28.21%   View 2: 32.54%
# - Fraction of zero weights:  View 0: 2%   View 1: 2%   View 2: 6%
# - Maximum correlation between factors: 0.19
# - Factor norms:  3.86 2.04 1.93 0.93 1.82 0.74 0.55 0.72
# - Tau per view (average):  View 0: 1.48   View 1: 1.43   View 2: 1259.37
#
#
# Iteration 54: time=0.43, ELBO=-2551652.09, deltaELBO=429.267 (0.00295846%), Factors=8
# - ELBO decomposition:  Z=-6487.37  W=-102015.30  Tau=-111369.49  Y=-2330867.63  AlphaW=-829.27  ThetaW=-83.03
# - Time spent in ELBO computation: 2.9%
# - Variance explained:  View 0: 26.57%   View 1: 28.27%   View 2: 32.54%
# - Fraction of zero weights:  View 0: 2%   View 1: 2%   View 2: 6%
# - Maximum correlation between factors: 0.19
# - Factor norms:  3.86 2.03 1.93 0.92 1.82 0.74 0.55 0.72
# - Tau per view (average):  View 0: 1.48   View 1: 1.44   View 2: 1259.42
#
#
# Iteration 55: time=0.79, ELBO=-2551340.47, deltaELBO=311.617 (0.00214762%), Factors=8
# - ELBO decomposition:  Z=-6487.24  W=-102016.60  Tau=-111369.62  Y=-2330554.24  AlphaW=-829.27  ThetaW=-83.50
# - Time spent in ELBO computation: 1.3%
# - Variance explained:  View 0: 26.60%   View 1: 28.31%   View 2: 32.54%
# - Fraction of zero weights:  View 0: 2%   View 1: 2%   View 2: 7%
# - Maximum correlation between factors: 0.19
# - Factor norms:  3.86 2.02 1.93 0.91 1.82 0.74 0.55 0.72
# - Tau per view (average):  View 0: 1.48   View 1: 1.44   View 2: 1259.46
#
#
# Iteration 56: time=0.45, ELBO=-2551106.88, deltaELBO=233.590 (0.00160988%), Factors=8
# - ELBO decomposition:  Z=-6487.11  W=-102014.81  Tau=-111369.74  Y=-2330322.01  AlphaW=-829.27  ThetaW=-83.95
# - Time spent in ELBO computation: 6.5%
# - Variance explained:  View 0: 26.63%   View 1: 28.34%   View 2: 32.54%
# - Fraction of zero weights:  View 0: 2%   View 1: 2%   View 2: 7%
# - Maximum correlation between factors: 0.19
# - Factor norms:  3.86 2.01 1.93 0.91 1.82 0.74 0.55 0.72
# - Tau per view (average):  View 0: 1.48   View 1: 1.44   View 2: 1259.50
#
#
# Iteration 57: time=0.46, ELBO=-2550925.82, deltaELBO=181.061 (0.00124785%), Factors=8
# - ELBO decomposition:  Z=-6486.99  W=-102013.28  Tau=-111369.85  Y=-2330142.06  AlphaW=-829.27  ThetaW=-84.37
# - Time spent in ELBO computation: 3.0%
# - Variance explained:  View 0: 26.65%   View 1: 28.37%   View 2: 32.54%
# - Fraction of zero weights:  View 0: 2%   View 1: 2%   View 2: 7%
# - Maximum correlation between factors: 0.19
# - Factor norms:  3.86 2.00 1.93 0.91 1.82 0.74 0.55 0.72
# - Tau per view (average):  View 0: 1.48   View 1: 1.44   View 2: 1259.53
#
#
# Iteration 58: time=0.42, ELBO=-2550781.12, deltaELBO=144.700 (0.00099726%), Factors=8
# - ELBO decomposition:  Z=-6486.88  W=-102012.60  Tau=-111369.95  Y=-2329997.64  AlphaW=-829.27  ThetaW=-84.78
# - Time spent in ELBO computation: 4.4%
# - Variance explained:  View 0: 26.66%   View 1: 28.39%   View 2: 32.54%
# - Fraction of zero weights:  View 0: 2%   View 1: 2%   View 2: 7%
# - Maximum correlation between factors: 0.19
# - Factor norms:  3.86 2.00 1.93 0.91 1.82 0.74 0.55 0.72
# - Tau per view (average):  View 0: 1.48   View 1: 1.44   View 2: 1259.57
#
#
# Iteration 59: time=0.42, ELBO=-2550662.36, deltaELBO=118.767 (0.00081853%), Factors=8
# - ELBO decomposition:  Z=-6486.77  W=-102012.71  Tau=-111370.05  Y=-2329878.38  AlphaW=-829.27  ThetaW=-85.17
# - Time spent in ELBO computation: 4.0%
# - Variance explained:  View 0: 26.67%   View 1: 28.40%   View 2: 32.54%
# - Fraction of zero weights:  View 0: 2%   View 1: 2%   View 2: 7%
# - Maximum correlation between factors: 0.19
# - Factor norms:  3.86 1.99 1.93 0.90 1.82 0.74 0.55 0.72
# - Tau per view (average):  View 0: 1.48   View 1: 1.44   View 2: 1259.60
#
#
# Iteration 60: time=0.49, ELBO=-2550562.62, deltaELBO=99.735 (0.00068736%), Factors=8
# - ELBO decomposition:  Z=-6486.67  W=-102013.45  Tau=-111370.15  Y=-2329777.54  AlphaW=-829.27  ThetaW=-85.54
# - Time spent in ELBO computation: 2.0%
# - Variance explained:  View 0: 26.68%   View 1: 28.42%   View 2: 32.54%
# - Fraction of zero weights:  View 0: 2%   View 1: 2%   View 2: 7%
# - Maximum correlation between factors: 0.19
# - Factor norms:  3.86 1.99 1.93 0.90 1.82 0.74 0.55 0.72
# - Tau per view (average):  View 0: 1.48   View 1: 1.44   View 2: 1259.63
#
#
# Iteration 61: time=0.39, ELBO=-2550477.23, deltaELBO=85.393 (0.00058852%), Factors=8
# - ELBO decomposition:  Z=-6486.58  W=-102014.68  Tau=-111370.24  Y=-2329690.56  AlphaW=-829.27  ThetaW=-85.90
# - Time spent in ELBO computation: 2.5%
# - Variance explained:  View 0: 26.69%   View 1: 28.43%   View 2: 32.54%
# - Fraction of zero weights:  View 0: 2%   View 1: 1%   View 2: 7%
# - Maximum correlation between factors: 0.19
# - Factor norms:  3.86 1.99 1.93 0.90 1.82 0.74 0.55 0.72
# - Tau per view (average):  View 0: 1.48   View 1: 1.44   View 2: 1259.66
#
#
# Iteration 62: time=0.38, ELBO=-2550402.90, deltaELBO=74.326 (0.00051224%), Factors=8
# - ELBO decomposition:  Z=-6486.49  W=-102016.29  Tau=-111370.32  Y=-2329614.28  AlphaW=-829.27  ThetaW=-86.25
# - Time spent in ELBO computation: 2.4%
# - Variance explained:  View 0: 26.70%   View 1: 28.44%   View 2: 32.54%
# - Fraction of zero weights:  View 0: 2%   View 1: 1%   View 2: 7%
# - Maximum correlation between factors: 0.19
# - Factor norms:  3.86 1.98 1.93 0.90 1.82 0.74 0.55 0.72
# - Tau per view (average):  View 0: 1.48   View 1: 1.44   View 2: 1259.69
#
#
# Iteration 63: time=0.38, ELBO=-2550337.30, deltaELBO=65.603 (0.00045213%), Factors=8
# - ELBO decomposition:  Z=-6486.41  W=-102018.22  Tau=-111370.41  Y=-2329546.41  AlphaW=-829.27  ThetaW=-86.59
# - Time spent in ELBO computation: 4.1%
# - Variance explained:  View 0: 26.71%   View 1: 28.44%   View 2: 32.54%
# - Fraction of zero weights:  View 0: 1%   View 1: 1%   View 2: 8%
# - Maximum correlation between factors: 0.19
# - Factor norms:  3.86 1.98 1.93 0.90 1.82 0.74 0.55 0.72
# - Tau per view (average):  View 0: 1.48   View 1: 1.44   View 2: 1259.72
#
#
# Iteration 64: time=0.56, ELBO=-2550278.70, deltaELBO=58.597 (0.00040384%), Factors=8
# - ELBO decomposition:  Z=-6486.33  W=-102020.40  Tau=-111370.49  Y=-2329485.30  AlphaW=-829.27  ThetaW=-86.92
# - Time spent in ELBO computation: 1.5%
# - Variance explained:  View 0: 26.71%   View 1: 28.45%   View 2: 32.54%
# - Fraction of zero weights:  View 0: 1%   View 1: 1%   View 2: 8%
# - Maximum correlation between factors: 0.19
# - Factor norms:  3.86 1.97 1.93 0.90 1.82 0.74 0.55 0.72
# - Tau per view (average):  View 0: 1.48   View 1: 1.44   View 2: 1259.75
#
#
# Iteration 65: time=0.43, ELBO=-2550225.83, deltaELBO=52.876 (0.00036442%), Factors=8
# - ELBO decomposition:  Z=-6486.25  W=-102022.81  Tau=-111370.57  Y=-2329429.69  AlphaW=-829.27  ThetaW=-87.24
# - Time spent in ELBO computation: 5.6%
# - Variance explained:  View 0: 26.72%   View 1: 28.46%   View 2: 32.54%
# - Fraction of zero weights:  View 0: 1%   View 1: 1%   View 2: 8%
# - Maximum correlation between factors: 0.19
# - Factor norms:  3.86 1.97 1.93 0.90 1.82 0.74 0.55 0.72
# - Tau per view (average):  View 0: 1.48   View 1: 1.44   View 2: 1259.77
#
#
# Iteration 66: time=0.41, ELBO=-2550177.69, deltaELBO=48.135 (0.00033174%), Factors=8
# - ELBO decomposition:  Z=-6486.18  W=-102025.40  Tau=-111370.65  Y=-2329378.65  AlphaW=-829.27  ThetaW=-87.55
# - Time spent in ELBO computation: 5.0%
# - Variance explained:  View 0: 26.72%   View 1: 28.46%   View 2: 32.54%
# - Fraction of zero weights:  View 0: 1%   View 1: 1%   View 2: 8%
# - Maximum correlation between factors: 0.19
# - Factor norms:  3.86 1.97 1.93 0.90 1.82 0.74 0.55 0.72
# - Tau per view (average):  View 0: 1.48   View 1: 1.44   View 2: 1259.80
#
#
# Iteration 67: time=0.46, ELBO=-2550133.54, deltaELBO=44.154 (0.00030431%), Factors=8
# - ELBO decomposition:  Z=-6486.10  W=-102028.15  Tau=-111370.72  Y=-2329331.44  AlphaW=-829.27  ThetaW=-87.85
# - Time spent in ELBO computation: 3.2%
# - Variance explained:  View 0: 26.73%   View 1: 28.47%   View 2: 32.54%
# - Fraction of zero weights:  View 0: 1%   View 1: 1%   View 2: 9%
# - Maximum correlation between factors: 0.19
# - Factor norms:  3.86 1.96 1.93 0.90 1.82 0.74 0.55 0.72
# - Tau per view (average):  View 0: 1.48   View 1: 1.44   View 2: 1259.82
#
#
# Iteration 68: time=0.45, ELBO=-2550092.77, deltaELBO=40.772 (0.00028099%), Factors=8
# - ELBO decomposition:  Z=-6486.03  W=-102031.02  Tau=-111370.80  Y=-2329287.50  AlphaW=-829.27  ThetaW=-88.15
# - Time spent in ELBO computation: 3.5%
# - Variance explained:  View 0: 26.73%   View 1: 28.47%   View 2: 32.54%
# - Fraction of zero weights:  View 0: 1%   View 1: 1%   View 2: 9%
# - Maximum correlation between factors: 0.19
# - Factor norms:  3.86 1.96 1.93 0.90 1.82 0.74 0.55 0.72
# - Tau per view (average):  View 0: 1.48   View 1: 1.44   View 2: 1259.85
#
#
# Iteration 69: time=0.46, ELBO=-2550054.90, deltaELBO=37.867 (0.00026098%), Factors=8
# - ELBO decomposition:  Z=-6485.97  W=-102034.00  Tau=-111370.87  Y=-2329246.37  AlphaW=-829.27  ThetaW=-88.44
# - Time spent in ELBO computation: 4.5%
# - Variance explained:  View 0: 26.74%   View 1: 28.47%   View 2: 32.55%
# - Fraction of zero weights:  View 0: 1%   View 1: 1%   View 2: 10%
# - Maximum correlation between factors: 0.19
# - Factor norms:  3.86 1.96 1.93 0.90 1.82 0.74 0.55 0.72
# - Tau per view (average):  View 0: 1.48   View 1: 1.44   View 2: 1259.87
#
#
# Iteration 70: time=0.44, ELBO=-2550019.55, deltaELBO=35.349 (0.00024362%), Factors=8
# - ELBO decomposition:  Z=-6485.90  W=-102037.06  Tau=-111370.94  Y=-2329207.67  AlphaW=-829.27  ThetaW=-88.72
# - Time spent in ELBO computation: 2.3%
# - Variance explained:  View 0: 26.74%   View 1: 28.48%   View 2: 32.55%
# - Fraction of zero weights:  View 0: 1%   View 1: 1%   View 2: 10%
# - Maximum correlation between factors: 0.18
# - Factor norms:  3.86 1.95 1.93 0.90 1.82 0.74 0.55 0.72
# - Tau per view (average):  View 0: 1.48   View 1: 1.44   View 2: 1259.90
#
#
# Iteration 71: time=0.39, ELBO=-2549986.40, deltaELBO=33.148 (0.00022845%), Factors=8
# - ELBO decomposition:  Z=-6485.83  W=-102040.18  Tau=-111371.00  Y=-2329171.12  AlphaW=-829.27  ThetaW=-89.00
# - Time spent in ELBO computation: 2.2%
# - Variance explained:  View 0: 26.74%   View 1: 28.48%   View 2: 32.55%
# - Fraction of zero weights:  View 0: 1%   View 1: 1%   View 2: 11%
# - Maximum correlation between factors: 0.18
# - Factor norms:  3.86 1.95 1.93 0.90 1.82 0.74 0.55 0.72
# - Tau per view (average):  View 0: 1.48   View 1: 1.44   View 2: 1259.92
#
#
# Iteration 72: time=0.37, ELBO=-2549955.19, deltaELBO=31.208 (0.00021508%), Factors=8
# - ELBO decomposition:  Z=-6485.77  W=-102043.35  Tau=-111371.07  Y=-2329136.47  AlphaW=-829.27  ThetaW=-89.27
# - Time spent in ELBO computation: 2.4%
# - Variance explained:  View 0: 26.75%   View 1: 28.48%   View 2: 32.55%
# - Fraction of zero weights:  View 0: 1%   View 1: 1%   View 2: 11%
# - Maximum correlation between factors: 0.18
# - Factor norms:  3.86 1.95 1.93 0.90 1.82 0.74 0.55 0.72
# - Tau per view (average):  View 0: 1.48   View 1: 1.44   View 2: 1259.94
#
#
# Iteration 73: time=0.37, ELBO=-2549925.71, deltaELBO=29.487 (0.00020322%), Factors=8
# - ELBO decomposition:  Z=-6485.70  W=-102046.56  Tau=-111371.14  Y=-2329103.52  AlphaW=-829.27  ThetaW=-89.53
# - Time spent in ELBO computation: 3.1%
# - Variance explained:  View 0: 26.75%   View 1: 28.49%   View 2: 32.55%
# - Fraction of zero weights:  View 0: 1%   View 1: 1%   View 2: 12%
# - Maximum correlation between factors: 0.18
# - Factor norms:  3.86 1.94 1.93 0.90 1.82 0.74 0.55 0.72
# - Tau per view (average):  View 0: 1.48   View 1: 1.44   View 2: 1259.96
#
#
# Iteration 74: time=0.41, ELBO=-2549897.76, deltaELBO=27.949 (0.00019262%), Factors=8
# - ELBO decomposition:  Z=-6485.64  W=-102049.78  Tau=-111371.20  Y=-2329072.08  AlphaW=-829.27  ThetaW=-89.79
# - Time spent in ELBO computation: 3.4%
# - Variance explained:  View 0: 26.75%   View 1: 28.49%   View 2: 32.55%
# - Fraction of zero weights:  View 0: 1%   View 1: 1%   View 2: 12%
# - Maximum correlation between factors: 0.18
# - Factor norms:  3.86 1.94 1.93 0.90 1.82 0.74 0.55 0.72
# - Tau per view (average):  View 0: 1.48   View 1: 1.44   View 2: 1259.98
#
#
# Iteration 75: time=0.46, ELBO=-2549871.19, deltaELBO=26.568 (0.00018310%), Factors=8
# - ELBO decomposition:  Z=-6485.57  W=-102053.01  Tau=-111371.26  Y=-2329042.03  AlphaW=-829.27  ThetaW=-90.05
# - Time spent in ELBO computation: 2.5%
# - Variance explained:  View 0: 26.75%   View 1: 28.49%   View 2: 32.56%
# - Fraction of zero weights:  View 0: 1%   View 1: 1%   View 2: 13%
# - Maximum correlation between factors: 0.18
# - Factor norms:  3.86 1.94 1.93 0.90 1.82 0.74 0.55 0.72
# - Tau per view (average):  View 0: 1.48   View 1: 1.44   View 2: 1260.00
#
#
# Iteration 76: time=0.39, ELBO=-2549845.87, deltaELBO=25.321 (0.00017451%), Factors=8
# - ELBO decomposition:  Z=-6485.51  W=-102056.25  Tau=-111371.32  Y=-2329013.23  AlphaW=-829.27  ThetaW=-90.30
# - Time spent in ELBO computation: 2.3%
# - Variance explained:  View 0: 26.76%   View 1: 28.49%   View 2: 32.56%
# - Fraction of zero weights:  View 0: 1%   View 1: 1%   View 2: 13%
# - Maximum correlation between factors: 0.18
# - Factor norms:  3.86 1.94 1.93 0.90 1.82 0.74 0.55 0.72
# - Tau per view (average):  View 0: 1.48   View 1: 1.44   View 2: 1260.02
#
#
# Iteration 77: time=0.54, ELBO=-2549821.68, deltaELBO=24.189 (0.00016670%), Factors=8
# - ELBO decomposition:  Z=-6485.45  W=-102059.47  Tau=-111371.38  Y=-2328985.58  AlphaW=-829.27  ThetaW=-90.54
# - Time spent in ELBO computation: 2.0%
# - Variance explained:  View 0: 26.76%   View 1: 28.50%   View 2: 32.56%
# - Fraction of zero weights:  View 0: 1%   View 1: 1%   View 2: 14%
# - Maximum correlation between factors: 0.18
# - Factor norms:  3.86 1.93 1.93 0.90 1.82 0.74 0.55 0.72
# - Tau per view (average):  View 0: 1.48   View 1: 1.44   View 2: 1260.04
#
#
# Iteration 78: time=0.37, ELBO=-2549798.52, deltaELBO=23.157 (0.00015959%), Factors=8
# - ELBO decomposition:  Z=-6485.38  W=-102062.67  Tau=-111371.44  Y=-2328958.98  AlphaW=-829.27  ThetaW=-90.79
# - Time spent in ELBO computation: 3.5%
# - Variance explained:  View 0: 26.76%   View 1: 28.50%   View 2: 32.56%
# - Fraction of zero weights:  View 0: 1%   View 1: 1%   View 2: 14%
# - Maximum correlation between factors: 0.18
# - Factor norms:  3.86 1.93 1.93 0.90 1.82 0.74 0.55 0.73
# - Tau per view (average):  View 0: 1.48   View 1: 1.44   View 2: 1260.06
#
#
# Iteration 79: time=0.37, ELBO=-2549776.31, deltaELBO=22.213 (0.00015309%), Factors=8
# - ELBO decomposition:  Z=-6485.32  W=-102065.86  Tau=-111371.49  Y=-2328933.35  AlphaW=-829.27  ThetaW=-91.02
# - Time spent in ELBO computation: 2.7%
# - Variance explained:  View 0: 26.76%   View 1: 28.50%   View 2: 32.56%
# - Fraction of zero weights:  View 0: 1%   View 1: 1%   View 2: 14%
# - Maximum correlation between factors: 0.18
# - Factor norms:  3.86 1.93 1.93 0.90 1.82 0.74 0.55 0.73
# - Tau per view (average):  View 0: 1.48   View 1: 1.44   View 2: 1260.08
#
#
# Iteration 80: time=0.45, ELBO=-2549754.97, deltaELBO=21.345 (0.00014711%), Factors=8
# - ELBO decomposition:  Z=-6485.26  W=-102069.01  Tau=-111371.55  Y=-2328908.63  AlphaW=-829.27  ThetaW=-91.25
# - Time spent in ELBO computation: 4.1%
# - Variance explained:  View 0: 26.76%   View 1: 28.50%   View 2: 32.57%
# - Fraction of zero weights:  View 0: 1%   View 1: 1%   View 2: 15%
# - Maximum correlation between factors: 0.18
# - Factor norms:  3.86 1.92 1.94 0.90 1.82 0.74 0.55 0.73
# - Tau per view (average):  View 0: 1.48   View 1: 1.44   View 2: 1260.10
#
#
# Iteration 81: time=0.45, ELBO=-2549734.42, deltaELBO=20.546 (0.00014160%), Factors=8
# - ELBO decomposition:  Z=-6485.20  W=-102072.13  Tau=-111371.60  Y=-2328884.75  AlphaW=-829.27  ThetaW=-91.48
# - Time spent in ELBO computation: 2.0%
# - Variance explained:  View 0: 26.77%   View 1: 28.50%   View 2: 32.57%
# - Fraction of zero weights:  View 0: 1%   View 1: 1%   View 2: 15%
# - Maximum correlation between factors: 0.18
# - Factor norms:  3.86 1.92 1.94 0.90 1.82 0.74 0.55 0.73
# - Tau per view (average):  View 0: 1.48   View 1: 1.44   View 2: 1260.12
#
#
# Iteration 82: time=0.49, ELBO=-2549714.61, deltaELBO=19.807 (0.00013651%), Factors=8
# - ELBO decomposition:  Z=-6485.13  W=-102075.21  Tau=-111371.65  Y=-2328861.65  AlphaW=-829.27  ThetaW=-91.70
# - Time spent in ELBO computation: 3.7%
# - Variance explained:  View 0: 26.77%   View 1: 28.50%   View 2: 32.57%
# - Fraction of zero weights:  View 0: 1%   View 1: 1%   View 2: 15%
# - Maximum correlation between factors: 0.18
# - Factor norms:  3.86 1.92 1.94 0.90 1.82 0.74 0.55 0.73
# - Tau per view (average):  View 0: 1.48   View 1: 1.44   View 2: 1260.13
#
#
# Iteration 83: time=0.37, ELBO=-2549695.49, deltaELBO=19.122 (0.00013179%), Factors=8
# - ELBO decomposition:  Z=-6485.07  W=-102078.24  Tau=-111371.70  Y=-2328839.28  AlphaW=-829.27  ThetaW=-91.92
# - Time spent in ELBO computation: 4.2%
# - Variance explained:  View 0: 26.77%   View 1: 28.51%   View 2: 32.57%
# - Fraction of zero weights:  View 0: 1%   View 1: 1%   View 2: 15%
# - Maximum correlation between factors: 0.18
# - Factor norms:  3.86 1.92 1.94 0.90 1.82 0.74 0.55 0.73
# - Tau per view (average):  View 0: 1.48   View 1: 1.44   View 2: 1260.15
#
#
# Iteration 84: time=0.43, ELBO=-2549677.00, deltaELBO=18.486 (0.00012740%), Factors=8
# - ELBO decomposition:  Z=-6485.01  W=-102081.23  Tau=-111371.75  Y=-2328817.61  AlphaW=-829.27  ThetaW=-92.14
# - Time spent in ELBO computation: 2.7%
# - Variance explained:  View 0: 26.77%   View 1: 28.51%   View 2: 32.58%
# - Fraction of zero weights:  View 0: 1%   View 1: 1%   View 2: 16%
# - Maximum correlation between factors: 0.18
# - Factor norms:  3.86 1.91 1.94 0.90 1.82 0.74 0.55 0.73
# - Tau per view (average):  View 0: 1.48   View 1: 1.44   View 2: 1260.17
#
#
# Iteration 85: time=0.49, ELBO=-2549659.11, deltaELBO=17.893 (0.00012331%), Factors=8
# - ELBO decomposition:  Z=-6484.95  W=-102084.17  Tau=-111371.80  Y=-2328796.58  AlphaW=-829.27  ThetaW=-92.35
# - Time spent in ELBO computation: 3.7%
# - Variance explained:  View 0: 26.77%   View 1: 28.51%   View 2: 32.58%
# - Fraction of zero weights:  View 0: 1%   View 1: 1%   View 2: 16%
# - Maximum correlation between factors: 0.18
# - Factor norms:  3.86 1.91 1.94 0.91 1.82 0.74 0.55 0.73
# - Tau per view (average):  View 0: 1.48   View 1: 1.44   View 2: 1260.18
#
#
# Iteration 86: time=0.37, ELBO=-2549641.77, deltaELBO=17.339 (0.00011950%), Factors=8
# - ELBO decomposition:  Z=-6484.89  W=-102087.06  Tau=-111371.84  Y=-2328776.16  AlphaW=-829.27  ThetaW=-92.56
# - Time spent in ELBO computation: 2.5%
# - Variance explained:  View 0: 26.77%   View 1: 28.51%   View 2: 32.58%
# - Fraction of zero weights:  View 0: 1%   View 1: 1%   View 2: 16%
# - Maximum correlation between factors: 0.18
# - Factor norms:  3.86 1.91 1.94 0.91 1.82 0.74 0.55 0.73
# - Tau per view (average):  View 0: 1.48   View 1: 1.44   View 2: 1260.20
#
#
# Iteration 87: time=0.40, ELBO=-2549624.95, deltaELBO=16.821 (0.00011593%), Factors=8
# - ELBO decomposition:  Z=-6484.83  W=-102089.89  Tau=-111371.89  Y=-2328756.32  AlphaW=-829.27  ThetaW=-92.76
# - Time spent in ELBO computation: 2.4%
# - Variance explained:  View 0: 26.77%   View 1: 28.51%   View 2: 32.58%
# - Fraction of zero weights:  View 0: 1%   View 1: 1%   View 2: 16%
# - Maximum correlation between factors: 0.18
# ...
# - Maximum correlation between factors: 0.18
# - Factor norms:  3.86 1.82 1.94 0.92 1.82 0.74 0.55 0.73
# - Tau per view (average):  View 0: 1.48   View 1: 1.44   View 2: 1260.53
#
#
# Iteration 119: time=0.34, ELBO=-2549243.76, deltaELBO=9.150 (0.00006306%), Factors=8
# - ELBO decomposition:  Z=-6483.05  W=-102148.63  Tau=-111372.87  Y=-2328312.78  AlphaW=-829.27  ThetaW=-97.15
# - Time spent in ELBO computation: 3.5%
# - Variance explained:  View 0: 26.79%   View 1: 28.53%   View 2: 32.64%
# - Fraction of zero weights:  View 0: 1%   View 1: 1%   View 2: 17%
# - Maximum correlation between factors: 0.18
# - Factor norms:  3.86 1.82 1.94 0.92 1.82 0.74 0.55 0.73
# - Tau per view (average):  View 0: 1.48   View 1: 1.44   View 2: 1260.54
#
#
# Iteration 120: time=0.34, ELBO=-2549234.71, deltaELBO=9.043 (0.00006232%), Factors=8
# - ELBO decomposition:  Z=-6483.00  W=-102149.55  Tau=-111372.89  Y=-2328302.77  AlphaW=-829.27  ThetaW=-97.23
# - Time spent in ELBO computation: 4.2%
# - Variance explained:  View 0: 26.79%   View 1: 28.53%   View 2: 32.65%
# - Fraction of zero weights:  View 0: 1%   View 1: 1%   View 2: 17%
# - Maximum correlation between factors: 0.18
# - Factor norms:  3.86 1.82 1.94 0.92 1.82 0.74 0.55 0.73
# - Tau per view (average):  View 0: 1.48   View 1: 1.44   View 2: 1260.55
#
#
# Iteration 121: time=0.37, ELBO=-2549225.77, deltaELBO=8.940 (0.00006161%), Factors=8
# - ELBO decomposition:  Z=-6482.95  W=-102150.42  Tau=-111372.91  Y=-2328292.91  AlphaW=-829.27  ThetaW=-97.31
# - Time spent in ELBO computation: 3.6%
# - Variance explained:  View 0: 26.79%   View 1: 28.53%   View 2: 32.65%
# - Fraction of zero weights:  View 0: 1%   View 1: 1%   View 2: 17%
# - Maximum correlation between factors: 0.18
# - Factor norms:  3.86 1.82 1.94 0.92 1.82 0.74 0.55 0.73
# - Tau per view (average):  View 0: 1.48   View 1: 1.44   View 2: 1260.55
#
#
# Iteration 122: time=0.48, ELBO=-2549216.93, deltaELBO=8.840 (0.00006093%), Factors=8
# - ELBO decomposition:  Z=-6482.90  W=-102151.24  Tau=-111372.93  Y=-2328283.20  AlphaW=-829.27  ThetaW=-97.39
# - Time spent in ELBO computation: 3.0%
# - Variance explained:  View 0: 26.79%   View 1: 28.53%   View 2: 32.65%
# - Fraction of zero weights:  View 0: 1%   View 1: 1%   View 2: 17%
# - Maximum correlation between factors: 0.18
# - Factor norms:  3.86 1.81 1.94 0.92 1.83 0.74 0.55 0.73
# - Tau per view (average):  View 0: 1.48   View 1: 1.44   View 2: 1260.56
#
#
# Iteration 123: time=0.37, ELBO=-2549208.19, deltaELBO=8.745 (0.00006027%), Factors=8
# - ELBO decomposition:  Z=-6482.85  W=-102152.02  Tau=-111372.95  Y=-2328273.64  AlphaW=-829.27  ThetaW=-97.46
# - Time spent in ELBO computation: 5.3%
# - Variance explained:  View 0: 26.79%   View 1: 28.53%   View 2: 32.65%
# - Fraction of zero weights:  View 0: 1%   View 1: 1%   View 2: 17%
# - Maximum correlation between factors: 0.18
# - Factor norms:  3.86 1.81 1.94 0.92 1.83 0.74 0.55 0.73
# - Tau per view (average):  View 0: 1.48   View 1: 1.44   View 2: 1260.57
#
#
# Iteration 124: time=0.40, ELBO=-2549199.54, deltaELBO=8.652 (0.00005963%), Factors=8
# - ELBO decomposition:  Z=-6482.80  W=-102152.76  Tau=-111372.97  Y=-2328264.21  AlphaW=-829.27  ThetaW=-97.53
# - Time spent in ELBO computation: 5.3%
# - Variance explained:  View 0: 26.79%   View 1: 28.53%   View 2: 32.65%
# - Fraction of zero weights:  View 0: 1%   View 1: 1%   View 2: 17%
# - Maximum correlation between factors: 0.18
# - Factor norms:  3.86 1.81 1.95 0.92 1.83 0.74 0.55 0.73
# - Tau per view (average):  View 0: 1.48   View 1: 1.44   View 2: 1260.57
#
#
# Iteration 125: time=0.38, ELBO=-2549190.97, deltaELBO=8.563 (0.00005901%), Factors=8
# - ELBO decomposition:  Z=-6482.75  W=-102153.45  Tau=-111372.99  Y=-2328254.92  AlphaW=-829.27  ThetaW=-97.60
# - Time spent in ELBO computation: 5.2%
# - Variance explained:  View 0: 26.78%   View 1: 28.53%   View 2: 32.65%
# - Fraction of zero weights:  View 0: 1%   View 1: 1%   View 2: 17%
# - Maximum correlation between factors: 0.18
# - Factor norms:  3.86 1.81 1.95 0.92 1.83 0.74 0.55 0.73
# - Tau per view (average):  View 0: 1.48   View 1: 1.44   View 2: 1260.58
#
#
# Iteration 126: time=0.38, ELBO=-2549182.50, deltaELBO=8.476 (0.00005842%), Factors=8
# - ELBO decomposition:  Z=-6482.70  W=-102154.10  Tau=-111373.01  Y=-2328245.75  AlphaW=-829.27  ThetaW=-97.66
# - Time spent in ELBO computation: 3.5%
# - Variance explained:  View 0: 26.78%   View 1: 28.53%   View 2: 32.66%
# - Fraction of zero weights:  View 0: 1%   View 1: 1%   View 2: 17%
# - Maximum correlation between factors: 0.18
# - Factor norms:  3.86 1.80 1.95 0.92 1.83 0.74 0.55 0.73
# - Tau per view (average):  View 0: 1.48   View 1: 1.44   View 2: 1260.59
#
#
# Iteration 127: time=0.36, ELBO=-2549174.10, deltaELBO=8.393 (0.00005784%), Factors=8
# - ELBO decomposition:  Z=-6482.66  W=-102154.72  Tau=-111373.03  Y=-2328236.71  AlphaW=-829.27  ThetaW=-97.72
# - Time spent in ELBO computation: 2.8%
# - Variance explained:  View 0: 26.78%   View 1: 28.53%   View 2: 32.66%
# - Fraction of zero weights:  View 0: 1%   View 1: 1%   View 2: 17%
# - Maximum correlation between factors: 0.18
# - Factor norms:  3.86 1.80 1.95 0.93 1.83 0.74 0.55 0.73
# - Tau per view (average):  View 0: 1.48   View 1: 1.44   View 2: 1260.59
#
#
# Iteration 128: time=0.37, ELBO=-2549165.79, deltaELBO=8.312 (0.00005728%), Factors=8
# - ELBO decomposition:  Z=-6482.61  W=-102155.29  Tau=-111373.04  Y=-2328227.80  AlphaW=-829.27  ThetaW=-97.78
# - Time spent in ELBO computation: 4.9%
# - Variance explained:  View 0: 26.78%   View 1: 28.53%   View 2: 32.66%
# - Fraction of zero weights:  View 0: 1%   View 1: 1%   View 2: 17%
# - Maximum correlation between factors: 0.18
# - Factor norms:  3.86 1.80 1.95 0.93 1.83 0.74 0.55 0.73
# - Tau per view (average):  View 0: 1.48   View 1: 1.44   View 2: 1260.60
#
#
# Iteration 129: time=0.36, ELBO=-2549157.56, deltaELBO=8.234 (0.00005675%), Factors=8
# - ELBO decomposition:  Z=-6482.56  W=-102155.83  Tau=-111373.06  Y=-2328219.00  AlphaW=-829.27  ThetaW=-97.84
# - Time spent in ELBO computation: 2.6%
# - Variance explained:  View 0: 26.78%   View 1: 28.53%   View 2: 32.66%
# - Fraction of zero weights:  View 0: 1%   View 1: 1%   View 2: 17%
# - Maximum correlation between factors: 0.18
# - Factor norms:  3.86 1.80 1.95 0.93 1.83 0.74 0.55 0.73
# - Tau per view (average):  View 0: 1.48   View 1: 1.44   View 2: 1260.60
#
#
# Iteration 130: time=0.37, ELBO=-2549149.40, deltaELBO=8.158 (0.00005622%), Factors=8
# - ELBO decomposition:  Z=-6482.52  W=-102156.32  Tau=-111373.08  Y=-2328210.32  AlphaW=-829.27  ThetaW=-97.90
# - Time spent in ELBO computation: 6.5%
# - Variance explained:  View 0: 26.78%   View 1: 28.53%   View 2: 32.66%
# - Fraction of zero weights:  View 0: 1%   View 1: 1%   View 2: 17%
# - Maximum correlation between factors: 0.18
# - Factor norms:  3.86 1.79 1.95 0.93 1.83 0.74 0.55 0.73
# - Tau per view (average):  View 0: 1.48   View 1: 1.44   View 2: 1260.61
#
#
# Iteration 131: time=0.29, ELBO=-2549141.32, deltaELBO=8.085 (0.00005572%), Factors=8
# - ELBO decomposition:  Z=-6482.47  W=-102156.79  Tau=-111373.09  Y=-2328201.75  AlphaW=-829.27  ThetaW=-97.95
# - Time spent in ELBO computation: 4.7%
# - Variance explained:  View 0: 26.78%   View 1: 28.53%   View 2: 32.66%
# - Fraction of zero weights:  View 0: 1%   View 1: 1%   View 2: 17%
# - Maximum correlation between factors: 0.18
# - Factor norms:  3.86 1.79 1.95 0.93 1.83 0.74 0.55 0.73
# - Tau per view (average):  View 0: 1.48   View 1: 1.44   View 2: 1260.61
#
#
# Iteration 132: time=0.35, ELBO=-2549133.30, deltaELBO=8.014 (0.00005523%), Factors=8
# - ELBO decomposition:  Z=-6482.42  W=-102157.21  Tau=-111373.11  Y=-2328193.29  AlphaW=-829.27  ThetaW=-98.00
# - Time spent in ELBO computation: 2.7%
# - Variance explained:  View 0: 26.78%   View 1: 28.53%   View 2: 32.66%
# - Fraction of zero weights:  View 0: 1%   View 1: 1%   View 2: 17%
# - Maximum correlation between factors: 0.18
# - Factor norms:  3.86 1.79 1.95 0.93 1.83 0.73 0.55 0.73
# - Tau per view (average):  View 0: 1.48   View 1: 1.44   View 2: 1260.62
#
#
# Iteration 133: time=0.39, ELBO=-2549125.36, deltaELBO=7.946 (0.00005476%), Factors=8
# - ELBO decomposition:  Z=-6482.38  W=-102157.60  Tau=-111373.12  Y=-2328184.93  AlphaW=-829.27  ThetaW=-98.05
# - Time spent in ELBO computation: 2.6%
# - Variance explained:  View 0: 26.78%   View 1: 28.53%   View 2: 32.67%
# - Fraction of zero weights:  View 0: 1%   View 1: 1%   View 2: 17%
# - Maximum correlation between factors: 0.18
# - Factor norms:  3.86 1.79 1.95 0.93 1.83 0.73 0.55 0.73
# - Tau per view (average):  View 0: 1.48   View 1: 1.44   View 2: 1260.62
#
#
# Iteration 134: time=0.33, ELBO=-2549117.48, deltaELBO=7.879 (0.00005430%), Factors=8
# - ELBO decomposition:  Z=-6482.33  W=-102157.96  Tau=-111373.14  Y=-2328176.68  AlphaW=-829.27  ThetaW=-98.10
# - Time spent in ELBO computation: 3.6%
# - Variance explained:  View 0: 26.78%   View 1: 28.54%   View 2: 32.67%
# - Fraction of zero weights:  View 0: 1%   View 1: 1%   View 2: 17%
# - Maximum correlation between factors: 0.18
# - Factor norms:  3.86 1.78 1.95 0.93 1.83 0.73 0.55 0.73
# - Tau per view (average):  View 0: 1.48   View 1: 1.44   View 2: 1260.63
#
#
# Iteration 135: time=0.30, ELBO=-2549109.66, deltaELBO=7.815 (0.00005386%), Factors=8
# - ELBO decomposition:  Z=-6482.29  W=-102158.28  Tau=-111373.15  Y=-2328168.53  AlphaW=-829.27  ThetaW=-98.15
# - Time spent in ELBO computation: 8.6%
# - Variance explained:  View 0: 26.78%   View 1: 28.54%   View 2: 32.67%
# - Fraction of zero weights:  View 0: 1%   View 1: 1%   View 2: 17%
# - Maximum correlation between factors: 0.18
# - Factor norms:  3.86 1.78 1.95 0.93 1.83 0.73 0.55 0.73
# - Tau per view (average):  View 0: 1.48   View 1: 1.44   View 2: 1260.63
#
#
# Iteration 136: time=0.42, ELBO=-2549101.91, deltaELBO=7.752 (0.00005343%), Factors=8
# - ELBO decomposition:  Z=-6482.24  W=-102158.57  Tau=-111373.17  Y=-2328160.47  AlphaW=-829.27  ThetaW=-98.19
# - Time spent in ELBO computation: 3.7%
# - Variance explained:  View 0: 26.78%   View 1: 28.54%   View 2: 32.67%
# - Fraction of zero weights:  View 0: 1%   View 1: 1%   View 2: 17%
# - Maximum correlation between factors: 0.18
# - Factor norms:  3.86 1.78 1.95 0.93 1.83 0.73 0.55 0.73
# - Tau per view (average):  View 0: 1.48   View 1: 1.44   View 2: 1260.64
#
#
# Iteration 137: time=0.36, ELBO=-2549094.22, deltaELBO=7.692 (0.00005301%), Factors=8
# - ELBO decomposition:  Z=-6482.20  W=-102158.83  Tau=-111373.18  Y=-2328152.50  AlphaW=-829.27  ThetaW=-98.24
# - Time spent in ELBO computation: 3.6%
# - Variance explained:  View 0: 26.78%   View 1: 28.54%   View 2: 32.67%
# - Fraction of zero weights:  View 0: 1%   View 1: 1%   View 2: 17%
# - Maximum correlation between factors: 0.18
# - Factor norms:  3.86 1.78 1.95 0.93 1.83 0.73 0.55 0.73
# - Tau per view (average):  View 0: 1.48   View 1: 1.44   View 2: 1260.64
#
#
# Iteration 138: time=0.38, ELBO=-2549086.59, deltaELBO=7.633 (0.00005261%), Factors=8
# - ELBO decomposition:  Z=-6482.15  W=-102159.06  Tau=-111373.19  Y=-2328144.63  AlphaW=-829.27  ThetaW=-98.28
# - Time spent in ELBO computation: 3.1%
# - Variance explained:  View 0: 26.78%   View 1: 28.54%   View 2: 32.67%
# - Fraction of zero weights:  View 0: 1%   View 1: 1%   View 2: 17%
# - Maximum correlation between factors: 0.18
# - Factor norms:  3.85 1.78 1.95 0.93 1.83 0.73 0.55 0.73
# - Tau per view (average):  View 0: 1.48   View 1: 1.44   View 2: 1260.65
#
#
# Iteration 139: time=0.45, ELBO=-2549079.01, deltaELBO=7.576 (0.00005221%), Factors=8
# - ELBO decomposition:  Z=-6482.11  W=-102159.26  Tau=-111373.21  Y=-2328136.85  AlphaW=-829.27  ThetaW=-98.32
# - Time spent in ELBO computation: 3.9%
# - Variance explained:  View 0: 26.78%   View 1: 28.54%   View 2: 32.67%
# - Fraction of zero weights:  View 0: 1%   View 1: 1%   View 2: 17%
# - Maximum correlation between factors: 0.18
# - Factor norms:  3.85 1.77 1.95 0.93 1.83 0.73 0.55 0.73
# - Tau per view (average):  View 0: 1.48   View 1: 1.44   View 2: 1260.65
#
#
# Iteration 140: time=0.38, ELBO=-2549071.49, deltaELBO=7.521 (0.00005183%), Factors=8
# - ELBO decomposition:  Z=-6482.06  W=-102159.43  Tau=-111373.22  Y=-2328129.15  AlphaW=-829.27  ThetaW=-98.36
# - Time spent in ELBO computation: 2.5%
# - Variance explained:  View 0: 26.78%   View 1: 28.54%   View 2: 32.68%
# - Fraction of zero weights:  View 0: 1%   View 1: 1%   View 2: 17%
# - Maximum correlation between factors: 0.18
# - Factor norms:  3.85 1.77 1.95 0.93 1.83 0.73 0.55 0.73
# - Tau per view (average):  View 0: 1.48   View 1: 1.44   View 2: 1260.66
#
#
# Iteration 141: time=0.38, ELBO=-2549064.02, deltaELBO=7.467 (0.00005146%), Factors=8
# - ELBO decomposition:  Z=-6482.02  W=-102159.57  Tau=-111373.23  Y=-2328121.53  AlphaW=-829.27  ThetaW=-98.40
# - Time spent in ELBO computation: 4.7%
# - Variance explained:  View 0: 26.78%   View 1: 28.54%   View 2: 32.68%
# - Fraction of zero weights:  View 0: 1%   View 1: 1%   View 2: 17%
# - Maximum correlation between factors: 0.18
# - Factor norms:  3.85 1.77 1.95 0.93 1.83 0.73 0.55 0.73
# - Tau per view (average):  View 0: 1.48   View 1: 1.44   View 2: 1260.66
#
#
# Iteration 142: time=0.38, ELBO=-2549056.61, deltaELBO=7.415 (0.00005110%), Factors=8
# - ELBO decomposition:  Z=-6481.98  W=-102159.68  Tau=-111373.25  Y=-2328114.00  AlphaW=-829.27  ThetaW=-98.44
# - Time spent in ELBO computation: 2.4%
# - Variance explained:  View 0: 26.78%   View 1: 28.54%   View 2: 32.68%
# - Fraction of zero weights:  View 0: 1%   View 1: 1%   View 2: 17%
# - Maximum correlation between factors: 0.18
# - Factor norms:  3.85 1.77 1.95 0.93 1.83 0.73 0.55 0.73
# - Tau per view (average):  View 0: 1.48   View 1: 1.44   View 2: 1260.67
#
#
# Iteration 143: time=0.40, ELBO=-2549049.24, deltaELBO=7.365 (0.00005076%), Factors=8
# - ELBO decomposition:  Z=-6481.94  W=-102159.76  Tau=-111373.26  Y=-2328106.54  AlphaW=-829.27  ThetaW=-98.47
# - Time spent in ELBO computation: 3.8%
# - Variance explained:  View 0: 26.78%   View 1: 28.54%   View 2: 32.68%
# - Fraction of zero weights:  View 0: 1%   View 1: 1%   View 2: 17%
# - Maximum correlation between factors: 0.18
# - Factor norms:  3.85 1.77 1.95 0.93 1.83 0.73 0.55 0.73
# - Tau per view (average):  View 0: 1.48   View 1: 1.44   View 2: 1260.67
#
#
# Iteration 144: time=0.42, ELBO=-2549041.93, deltaELBO=7.315 (0.00005042%), Factors=8
# - ELBO decomposition:  Z=-6481.89  W=-102159.82  Tau=-111373.27  Y=-2328099.17  AlphaW=-829.27  ThetaW=-98.51
# - Time spent in ELBO computation: 2.2%
# - Variance explained:  View 0: 26.78%   View 1: 28.54%   View 2: 32.68%
# - Fraction of zero weights:  View 0: 1%   View 1: 1%   View 2: 17%
# - Maximum correlation between factors: 0.18
# - Factor norms:  3.85 1.76 1.95 0.93 1.83 0.73 0.55 0.73
# - Tau per view (average):  View 0: 1.48   View 1: 1.44   View 2: 1260.67
#
#
# Iteration 145: time=0.46, ELBO=-2549034.66, deltaELBO=7.268 (0.00005009%), Factors=8
# - ELBO decomposition:  Z=-6481.85  W=-102159.85  Tau=-111373.28  Y=-2328091.86  AlphaW=-829.27  ThetaW=-98.54
# - Time spent in ELBO computation: 3.1%
# - Variance explained:  View 0: 26.78%   View 1: 28.54%   View 2: 32.68%
# - Fraction of zero weights:  View 0: 1%   View 1: 1%   View 2: 17%
# - Maximum correlation between factors: 0.18
# - Factor norms:  3.85 1.76 1.95 0.93 1.83 0.73 0.55 0.73
# - Tau per view (average):  View 0: 1.48   View 1: 1.44   View 2: 1260.68
#
#
# Iteration 146: time=0.41, ELBO=-2549027.44, deltaELBO=7.222 (0.00004977%), Factors=8
# - ELBO decomposition:  Z=-6481.81  W=-102159.86  Tau=-111373.30  Y=-2328084.63  AlphaW=-829.27  ThetaW=-98.57
# - Time spent in ELBO computation: 4.9%
# - Variance explained:  View 0: 26.78%   View 1: 28.54%   View 2: 32.68%
# - Fraction of zero weights:  View 0: 1%   View 1: 1%   View 2: 17%
# - Maximum correlation between factors: 0.18
# - Factor norms:  3.85 1.76 1.95 0.93 1.83 0.73 0.55 0.73
# - Tau per view (average):  View 0: 1.48   View 1: 1.44   View 2: 1260.68
#
#
# Iteration 147: time=0.35, ELBO=-2549020.26, deltaELBO=7.177 (0.00004946%), Factors=8
# - ELBO decomposition:  Z=-6481.77  W=-102159.84  Tau=-111373.31  Y=-2328077.47  AlphaW=-829.27  ThetaW=-98.61
# - Time spent in ELBO computation: 7.5%
#
# Converged!
#
#
#
# #######################
# ## Training finished ##
# #######################
#
#
# Training complete!

# %%
outfile = "./PDAC_data/mofa_model.hdf5"
ent.save(outfile, save_data=True)
print(f"Model saved to {outfile}")
# Out:
# Warning: Output file ./PDAC_data/mofa_model.hdf5 already exists, it will be replaced
# Saving model in ./PDAC_data/mofa_model.hdf5...
# Model saved to ./PDAC_data/mofa_model.hdf5
